# %%
import pandas as pd

# %%
data_cars=pd.read_csv("M:/car_deko.csv")

# %%
data_cars
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
data_ev=pd.read_csv("M:/indian_ev.csv")

# %%
data_ev
# Out:
#     id                   Model          Manufacturer Vehicle Type  \
# 0    1           Aura 300 Plus          Ather Energy      Scooter
# 1    2       Pure EV Epluto 7G               Pure EV      Scooter
# 2    3   Bajaj Chetak Electric            Bajaj Auto      Scooter
# 3    4     Okinawa iPraise Pro      Okinawa Autotech      Scooter
# 4    5   Hero Electric Opto EV         Hero Motocorp      Scooter
# 5    6                Tork T6X           Tork Motors         Bike
# 6    7            Revolt RV400         Revolt Motors         Bike
# 7    8   Bajaj Chetak Electric            Bajaj Auto      Scooter
# 8    9              Ather 450X          Ather Energy      Scooter
# 9   10       Pure EV Epluto 7G               Pure EV      Scooter
# 10  11     Okinawa iPraise Pro      Okinawa Autotech      Scooter
# 11  12   Hero Electric Opto EV         Hero Motocorp      Scooter
# 12  13                Tork T6X           Tork Motors         Bike
# ...

# %%
data_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
data_cars.shape
# Out:
# (4340, 8)

# %%
data_ev.describe()
# Out:
#              id  Battery Capacity (kWh)  Range per Charge (km)  Charging Time  \
# count  50.00000               50.000000              50.000000      49.000000
# mean   25.50000                3.188000             120.160000       3.755102
# std    14.57738                0.950325              30.370743       0.947158
# min     1.00000                2.200000              75.000000       2.500000
# 25%    13.25000                2.550000             100.000000       3.000000
# 50%    25.50000                2.900000             118.000000       3.500000
# 75%    37.75000                3.500000             140.000000       4.500000
# max    50.00000                6.200000             200.000000       6.000000
#
#                Price  Power (HP or kW)  Top Speed (km/h)  Year of Manufacture
# count      49.000000         49.000000         49.000000            49.000000
# mean   120469.387755          6.795918         73.775510          2021.204082
# ...

# %%
data_cars.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,20))
sns.barplot(x=data_cars['fuel'],y=data_cars['name'])
# Out:
# <Axes: xlabel='fuel', ylabel='name'>

# %%
# Filter the dataset for rows where the 'fuel' is 'Electric'
electric_cars = data_cars[data_cars['fuel'] == 'Electric']

# Display the first few rows of the electric car data
electric_cars.head()
# Out:
#                      name  year  selling_price  km_driven      fuel  \
# 4145  Toyota Camry Hybrid  2006         310000      62000  Electric
#
#      seller_type transmission         owner
# 4145      Dealer    Automatic  Second Owner

# %%
##filtering the dataset for rows where the fuel is petrol
petrol_cars=data_cars[data_cars['fuel'] =='Petrol']
petrol_cars.head(6)
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 0              Maruti 800 AC  2007          60000      70000  Petrol
# 1   Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 3     Datsun RediGO T Option  2017         250000      46000  Petrol
# 5       Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6  Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7   Tata Indigo Grand Petrol  2014         240000      60000  Petrol
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 5  Individual       Manual   First Owner
# 6  Individual       Manual   First Owner
# 7  Individual       Manual  Second Owner

# %%
diesel_cars=data_cars[data_cars['fuel']=='Diesel']
diesel_cars.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 2          Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 4         Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 15         Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 17        Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 27  Hyundai Venue SX Opt Diesel  2019        1195000       5000  Diesel
#
#    seller_type transmission         owner
# 2   Individual       Manual   First Owner
# 4   Individual       Manual  Second Owner
# 15  Individual       Manual   First Owner
# 17  Individual       Manual  Second Owner
# 27      Dealer       Manual   First Owner

# %%
lpg_cars=data_cars[data_cars['fuel']=="LPG"]
lpg_cars.head()
# Out:
#                                           name  year  selling_price  \
# 157                     Maruti Wagon R DUO LPG  2014         210000
# 222  Maruti Omni LPG CARGO BSIII W IMMOBILISER  2009          80000
# 483                 Hyundai EON LPG Magna Plus  2012         180000
# 495          Hyundai Santro Xing GLS Audio LPG  2012         250000
# 657                      Hyundai i10 Magna LPG  2013         250000
#
#      km_driven fuel seller_type transmission         owner
# 157      90000  LPG  Individual       Manual   First Owner
# 222      90000  LPG  Individual       Manual  Second Owner
# 483      90000  LPG  Individual       Manual   First Owner
# 495     100000  LPG  Individual       Manual   First Owner
# 657      88600  LPG  Individual       Manual   First Owner

# %%
cng_cars=data_cars[data_cars['fuel']=="CNG"]
cng_cars.head()
# Out:
#                                        name  year  selling_price  km_driven  \
# 9                  Maruti Celerio Green VXI  2017         365000      78000
# 22                 Maruti Celerio Green VXI  2017         365000      78000
# 176                 Maruti Alto K10 LXI CNG  2020         282000      40000
# 351             Tata Indigo CS Emax CNG GLX  2014         185000      72000
# 352  Maruti Eeco 5 STR With AC Plus HTR CNG  2012         229999      75000
#
#     fuel seller_type transmission        owner
# 9    CNG  Individual       Manual  First Owner
# 22   CNG  Individual       Manual  First Owner
# 176  CNG  Individual       Manual  First Owner
# 351  CNG      Dealer       Manual  First Owner
# 352  CNG      Dealer       Manual  First Owner

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=diesel_cars['year'], y=diesel_cars['selling_price'])
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=petrol_cars['year'], y=petrol_cars['selling_price'])
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=lpg_cars['year'], y=lpg_cars['selling_price'])
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=cng_cars['year'], y=cng_cars['selling_price'])
plt.show()

# %%
sns.catplot(data=petrol_cars, x='name', kind='count', palette='viridis', height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('Brand',family='serif', size=12)
plt.ylabel('Count', family='serif', size=12)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title('Number of petrol cars made by brand', family='serif', size=15)
plt.show()
# Out:
# C:\Users\Mani\AppData\Local\Temp\ipykernel_1284\4021788188.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=petrol_cars, x='name', kind='count', palette='viridis', height=6, aspect=2)

# %%
sns.catplot(data=diesel_cars, x='name', kind='count', palette='viridis', height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('Brand',family='serif', size=12)
plt.ylabel('Count', family='serif', size=12)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title('Number of diesel cars made by brand', family='serif', size=15)
plt.show()
# Out:
# C:\Users\Mani\AppData\Local\Temp\ipykernel_1284\645469043.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=diesel_cars, x='name', kind='count', palette='viridis', height=6, aspect=2)

# %%
sns.catplot(data=lpg_cars, x='name', kind='count', palette='viridis', height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('Brand',family='serif', size=12)
plt.ylabel('Count', family='serif', size=12)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title('Number of lpg cars made by brand', family='serif', size=15)
plt.show()
# Out:
# C:\Users\Mani\AppData\Local\Temp\ipykernel_1284\2955308692.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=lpg_cars, x='name', kind='count', palette='viridis', height=6, aspect=2)

# %%
sns.catplot(data=cng_cars, x='name', kind='count', palette='viridis', height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('Brand',family='serif', size=12)
plt.ylabel('Count', family='serif', size=12)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title('Number of cng cars made by brand', family='serif', size=15)
plt.show()
# Out:
# C:\Users\Mani\AppData\Local\Temp\ipykernel_1284\3993326691.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=cng_cars, x='name', kind='count', palette='viridis', height=6, aspect=2)

# %%
sns.distplot(data_cars['selling_price'])
# Out:
# C:\Users\Mani\AppData\Local\Temp\ipykernel_1284\3018877797.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_cars['selling_price'])
# <Axes: xlabel='selling_price', ylabel='Density'>

# %%
# Create a pie chart
plt.figure(figsize=(8,8))
plt.pie(x=data_cars['fuel'].value_counts(), labels=data_cars['fuel'].value_counts().index, autopct='%1.1f%%')

# Add a legend
plt.legend(title='Fuel Types', loc='best')

# Show the plot
plt.show()

# %%
data_ev
# Out:
#     id                   Model          Manufacturer Vehicle Type  \
# 0    1           Aura 300 Plus          Ather Energy      Scooter
# 1    2       Pure EV Epluto 7G               Pure EV      Scooter
# 2    3   Bajaj Chetak Electric            Bajaj Auto      Scooter
# 3    4     Okinawa iPraise Pro      Okinawa Autotech      Scooter
# 4    5   Hero Electric Opto EV         Hero Motocorp      Scooter
# 5    6                Tork T6X           Tork Motors         Bike
# 6    7            Revolt RV400         Revolt Motors         Bike
# 7    8   Bajaj Chetak Electric            Bajaj Auto      Scooter
# 8    9              Ather 450X          Ather Energy      Scooter
# 9   10       Pure EV Epluto 7G               Pure EV      Scooter
# 10  11     Okinawa iPraise Pro      Okinawa Autotech      Scooter
# 11  12   Hero Electric Opto EV         Hero Motocorp      Scooter
# 12  13                Tork T6X           Tork Motors         Bike
# ...

# %%
data_ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      50 non-null     int64
#  1   Model                   50 non-null     object
#  2   Manufacturer            50 non-null     object
#  3   Vehicle Type            50 non-null     object
#  4   Battery Capacity (kWh)  50 non-null     float64
#  5   Range per Charge (km)   50 non-null     int64
#  6   Charging Time           49 non-null     float64
#  7   Price                   49 non-null     float64
#  8   Power (HP or kW)        49 non-null     float64
#  9   Top Speed (km/h)        49 non-null     float64
#  10  Year of Manufacture     49 non-null     float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.4+ KB

# %%
data_ev.columns
# Out:
# Index(['id', 'Model', 'Manufacturer', 'Vehicle Type', 'Battery Capacity (kWh)',
#        'Range per Charge (km)', 'Charging Time', 'Price', 'Power (HP or kW)',
#        'Top Speed (km/h)', 'Year of Manufacture'],
#       dtype='object')

# %%
data_ev.isnull().sum()
data_ev.dropna()
# Out:
#     id                   Model          Manufacturer Vehicle Type  \
# 0    1           Aura 300 Plus          Ather Energy      Scooter
# 1    2       Pure EV Epluto 7G               Pure EV      Scooter
# 2    3   Bajaj Chetak Electric            Bajaj Auto      Scooter
# 3    4     Okinawa iPraise Pro      Okinawa Autotech      Scooter
# 4    5   Hero Electric Opto EV         Hero Motocorp      Scooter
# 5    6                Tork T6X           Tork Motors         Bike
# 6    7            Revolt RV400         Revolt Motors         Bike
# 7    8   Bajaj Chetak Electric            Bajaj Auto      Scooter
# 8    9              Ather 450X          Ather Energy      Scooter
# 9   10       Pure EV Epluto 7G               Pure EV      Scooter
# 10  11     Okinawa iPraise Pro      Okinawa Autotech      Scooter
# 11  12   Hero Electric Opto EV         Hero Motocorp      Scooter
# 12  13                Tork T6X           Tork Motors         Bike
# ...

# %%
data_ev.value_counts()
# Out:
# id  Model                   Manufacturer          Vehicle Type  Battery Capacity (kWh)  Range per Charge (km)  Charging Time  Price     Power (HP or kW)  Top Speed (km/h)  Year of Manufacture
# 1   Aura 300 Plus           Ather Energy          Scooter       2.9                     116                    4.5            129000.0  6.0               80.0              2021.0                 1
# 26  Okinawa iPraise Pro     Okinawa Autotech      Scooter       2.5                     100                    3.0            85000.0   3.0               60.0              2021.0                 1
# 28  Ather 450X              Ather Energy          Scooter       2.9                     116                    4.5            149000.0  6.0               80.0              2021.0                 1
# 29  Pure EV Epluto 7G       Pure EV               Scooter       2.7                     120                    3.0            109000.0  5.0               80.0              2021.0                 1
# ...

# %%
data_ev.dtypes
# Out:
# id                          int64
# Model                      object
# Manufacturer               object
# Vehicle Type               object
# Battery Capacity (kWh)    float64
# Range per Charge (km)       int64
# Charging Time             float64
# Price                     float64
# Power (HP or kW)          float64
# Top Speed (km/h)          float64
# Year of Manufacture       float64
# dtype: object

# %%
data_ev.describe()
# Out:
#              id  Battery Capacity (kWh)  Range per Charge (km)  Charging Time  \
# count  50.00000               50.000000              50.000000      49.000000
# mean   25.50000                3.188000             120.160000       3.755102
# std    14.57738                0.950325              30.370743       0.947158
# min     1.00000                2.200000              75.000000       2.500000
# 25%    13.25000                2.550000             100.000000       3.000000
# 50%    25.50000                2.900000             118.000000       3.500000
# 75%    37.75000                3.500000             140.000000       4.500000
# max    50.00000                6.200000             200.000000       6.000000
#
#                Price  Power (HP or kW)  Top Speed (km/h)  Year of Manufacture
# count      49.000000         49.000000         49.000000            49.000000
# mean   120469.387755          6.795918         73.775510          2021.204082
# ...

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=data_ev,x=data_ev['Price'],y=data_ev['Model'])
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=data_ev,y=data_ev["Model"],x=data_ev["Charging Time"])
plt.show()

# %%
data_ev.columns
# Out:
# Index(['id', 'Model', 'Manufacturer', 'Vehicle Type', 'Battery Capacity (kWh)',
#        'Range per Charge (km)', 'Charging Time', 'Price', 'Power (HP or kW)',
#        'Top Speed (km/h)', 'Year of Manufacture'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.catplot(data=data_ev,y='Manufacturer',kind="count")

# %%
# Create a pie chart
plt.figure(figsize=(8,8))
plt.pie(x=data_ev["Manufacturer"].value_counts(), labels=data_ev['Manufacturer'].value_counts().index, autopct='%1.1f%%')

# Add a legend
plt.legend(title='Fuel Types', loc='best')

# Show the plot
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(8,8))
plt.pie(x=data_ev["Manufacturer"].value_counts(), labels=data_ev['Manufacturer'].value_counts().index, autopct='%1.1f%%')

# Add a legend
plt.legend(title='Fuel Types', loc='best')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=data_ev,x=data_ev['Price'],y=data_ev['Manufacturer'])
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=data_ev,x=data_ev["Top Speed (km/h)"],y=data_ev['Model'])
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=data_ev,x=data_ev["Top Speed (km/h)"],y=data_ev['Model'])
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("M:/indian_ev.csv")

# %%
data_clean = data.drop(columns=['id', 'Model', 'Manufacturer', 'Vehicle Type'])  # Drop non-numeric or irrelevant columns
data_clean = data_clean.dropna()  # Drop rows with missing values

# %%
X = data_clean.drop(columns=['Price'])
y = data_clean['Price']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 mae = mean_absolute_error(y_test, y_pred)
#       2 mse = mean_squared_error(y_test, y_pred)
#       3 rmse = np.sqrt(mse)
#
# NameError: name 'y_pred' is not defined
